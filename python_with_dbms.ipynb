# %%
a = int(input("enter first number"))
b = int(input("enter secand number"))
sum = a + b
print("sum =", sum)
# Out:
# enter first number 6
# enter secand number 7
# sum = 13

# %%
#area of rectangle
length = float(input("Enter length: "))
breadth = float(input("Enter breadth: "))

area = length * breadth
print("Area of rectangle =", area)
# Out:
# Enter length:  5
# Enter breadth:  6
# Area of rectangle = 30.0

# %%
P = float(input("Enter Principal amount: "))
R = float(input("Enter Rate of Interest: "))
T = float(input("Enter Time (in years): "))

SI = (P * R * T) / 100

print("Simple Interest =", SI)
# Out:
# Enter Principal amount:  10
# Enter Rate of Interest:  20
# Enter Time (in years):  30
# Simple Interest = 60.0

# %% [markdown]
# # WAP to calculate simple inreret
# # WAP to calculate area & volume of cube
# # WAP to convert celsius to fohrenheit

# %%
P = float(input("Enter Principal amount: "))
R = float(input("Enter Rate of Interest: "))
T = float(input("Enter Time (in years): "))

SI = (P * R * T) / 100

print("Simple Interest =", SI)
# Out:
# Enter Principal amount:  10
# Enter Rate of Interest:  20
# Enter Time (in years):  30
# Simple Interest = 60.0

# %%
# area and volume of cube
a = float(input("Side: "))
print("Area: ", 6*a*a)
print("Volume: ", a**3)
# Out:
# Side:  5
# Area:  150.0
# Volume:  125.0

# %%
# celsius to fahrenheit
c = float(input("Celsius: "))
f = (c*9/5) + 32
print("Fahrenheit:", f)
# Out:
# Celsius:  5
# Fahrenheit: 41.0

# %%
#WAP  to check if a person is eligible to votenor not
#WAP to check wheather input number is even or odd
#WAP to check if the given num is multiple of 5 or not
#WAP to check if the given num  is divisible by 35 or not
#WAP to print the last digit of a number  
#Input the sides of a triangle and print if it is  equilateral,isosceles,scalene
#check buzz number

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age:  20
# You are eligible to vote.

# %%
 #Program to check even or odd

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("The number is Even")
else:
    print("The number is Odd")
# Out:
# Enter a number:  5
# The number is Odd

# %%
 #WAP to check if the given number is a multiple of 5 or not

num = int(input("Enter a number: "))

if num % 5 == 0:
    print("The number is a multiple of 5")
else:
    print("The number is not a multiple of 5")
# Out:
# Enter a number:  15
# The number is a multiple of 5

# %%
#WAP to check if the given num  is divisible by 35 or not
num = int(input("Enter a number: "))

if num % 35 == 0:
    print("The number is divisible by 35")
else:
    print("The number is not divisible by 35")
# Out:
# Enter a number:  70
# The number is divisible by 35

# %%
#WAP to print the last digit of a number  
num = int(input("Enter number: "))
last_digit = num % 10
print("the last digit is", last_digit)
# Out:
# Enter number:  56
# the last digit is 6
